# %% [markdown]
# <a href="https://colab.research.google.com/github/Umargambo/UmarGambo/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List din ka
intruder_ids = [101, 102, 103]

# Canza 102 zuwa 999
intruder_ids[1] = 999

print(intruder_ids)
# Sakamakon zai zama: [101, 999, 103]
# Kara 104 a karshen list
intruder_ids.append(104)

print(intruder_ids)
# Sakamakon zai zama: [101, 999, 103, 104]
# Out:
# [101, 999, 103]
# [101, 999, 103, 104]
