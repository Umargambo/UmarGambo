# %% [markdown]
# <a href="https://colab.research.google.com/github/Umargambo/UmarGambo/blob/main/Loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
intruder_ids = [101, 999, 103, 104]

for x in intruder_ids:
    print("Intruder detected! ID is:")
    print(x)
# Out:
# Intruder detected! ID is:
# 101
# Intruder detected! ID is:
# 999
# Intruder detected! ID is:
# 103
# Intruder detected! ID is:
# 104
